# %% [markdown]
# ## POST Request using EDAMAM API

# %% [markdown]
# ### Import libraries

# %%
import requests
import json

# %% [markdown]
# ### Get ID and KEY
#
# I signed in to the API to get my ID and Key and have used to them for POST request

# %%
App_ID = '2****253'
App_key = 'fa8eb401fc*******89f76fb2590688d'

# %%
base_url = 'https://api.edamam.com/api/nutrition-details'
url=base_url+'?app_id='+App_ID+'&app_key='+App_key

# %% [markdown]
# ## Sending a POST request

# %%
head = {
   'content type':'application/json'
}

# %%
recipe = {
    'title':'Tea',
    'ingr': ['1 lt Water','15 gm tea leaf','50 ml milk','']
}

# %%
r = requests.post(url, headers=head, json=recipe)

# %%
r.ok
# Out:
# True

# %% [markdown]
# ## Inspecting the response

# %%
tea_info= r.json()

# %%
print(json.dumps(tea_info, indent=4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_c2d6f900d112464cbf0b23339f6730af",
#     "yield": 2.0,
#     "calories": 31,
#     "totalWeight": 1066.5663846203106,
#     "dietLabels": [
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "LOW_FAT_ABS",
#         "SUGAR_CONSCIOUS",
#         "LOW_POTASSIUM",
#         "KIDNEY_FRIENDLY",
#         "KETO_FRIENDLY",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "MEDITERRANEAN",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_OIL_ADDED",
#         "NO_SUGAR_ADDED",
#         "SULPHITE_FREE",
#         "KOSHER"
#     ],
#     "cautions": [
#         "SULFITES"
#     ],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 31.605494618389447,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 1.6759075001600934,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 0.962013073168792,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Monounsaturated",
#             "quantity": 0.4188690431169218,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Polyunsaturated",
#             "quantity": 0.10115445000960561,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 2.520186461774907,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars",
#             "quantity": 2.6041024233256835,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 1.6243411155397829,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 5.156638462031057,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 62.62354538673355,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 88.27001462095095,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 15.606638462031057,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 73.61762769880994,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 0.01846991538609317,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 0.2937956230951491,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 43.46576308106088,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 23.720536925342863,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 0.023720536925342862,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 0.08924719000832487,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 0.0458940823120764,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 0.018563898463311804,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 3.3283192310155285,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate (food)",
#             "quantity": 3.3283192310155285,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 0.23204873079139757,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 0.6703630000640374,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 0.0360964692342174,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.1546991538609317,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 1059.4004547658797,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 1.5802747309194725,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 2.578319231015528,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 4.81006536584396,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 0.840062153924969,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 3.2486822310795658,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 1.7188794873436855,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 2.609314391113898,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 8.827001462095096,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 3.7158663004835852,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 1.5663325042299987,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 0.10261064103385095,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 2.670869300864992,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 6.20939472586584,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 2.6356152139269846,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 1.9767114104452386,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 6.865168462178836,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 0.2868380144504775,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 1.4279921894855234,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 0.8320798077538821,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 9.668697116308232,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 4.469086667093582,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 0.240643128228116,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.12891596155077642,
#             "unit": "%"
#         }
#     },
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 31,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 6,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 15,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 10,
#             "unit": "kcal"
#         }
#     }
# }

# %%
tea_info.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'totalNutrientsKCal'])

# %%
tea_info['totalNutrients']
# Out:
# {'ENERC_KCAL': {'label': 'Energy',
#   'quantity': 31.605494618389447,
#   'unit': 'kcal'},
#  'FAT': {'label': 'Fat', 'quantity': 1.6759075001600934, 'unit': 'g'},
#  'FASAT': {'label': 'Saturated', 'quantity': 0.962013073168792, 'unit': 'g'},
#  'FAMS': {'label': 'Monounsaturated',
#   'quantity': 0.4188690431169218,
#   'unit': 'g'},
#  'FAPU': {'label': 'Polyunsaturated',
#   'quantity': 0.10115445000960561,
#   'unit': 'g'},
#  'CHOCDF': {'label': 'Carbs', 'quantity': 2.520186461774907, 'unit': 'g'},
#  'FIBTG': {'label': 'Fiber', 'quantity': 0.0, 'unit': 'g'},
#  'SUGAR': {'label': 'Sugars', 'quantity': 2.6041024233256835, 'unit': 'g'},
#  'PROCNT': {'label': 'Protein', 'quantity': 1.6243411155397829, 'unit': 'g'},
#  'CHOLE': {'label': 'Cholesterol',
#   'quantity': 5.156638462031057,
#   'unit': 'mg'},
#  'NA': {'label': 'Sodium', 'quantity': 62.62354538673355, 'unit': 'mg'},
#  'CA': {'label': 'Calcium', 'quantity': 88.27001462095095, 'unit': 'mg'},
#  'MG': {'label': 'Magnesium', 'quantity': 15.606638462031057, 'unit': 'mg'},
#  'K': {'label': 'Potassium', 'quantity': 73.61762769880994, 'unit': 'mg'},
#  'FE': {'label': 'Iron', 'quantity': 0.01846991538609317, 'unit': 'mg'},
#  'ZN': {'label': 'Zinc', 'quantity': 0.2937956230951491, 'unit': 'mg'},
#  'P': {'label': 'Phosphorus', 'quantity': 43.46576308106088, 'unit': 'mg'},
#  'VITA_RAE': {'label': 'Vitamin A',
#   'quantity': 23.720536925342863,
#   'unit': 'µg'},
#  'VITC': {'label': 'Vitamin C', 'quantity': 0.0, 'unit': 'mg'},
#  'THIA': {'label': 'Thiamin (B1)',
#   'quantity': 0.023720536925342862,
#   'unit': 'mg'},
#  'RIBF': {'label': 'Riboflavin (B2)',
#   'quantity': 0.08924719000832487,
#   'unit': 'mg'},
#  'NIA': {'label': 'Niacin (B3)', 'quantity': 0.0458940823120764, 'unit': 'mg'},
#  'VITB6A': {'label': 'Vitamin B6',
#   'quantity': 0.018563898463311804,
#   'unit': 'mg'},
#  'FOLDFE': {'label': 'Folate equivalent (total)',
#   'quantity': 3.3283192310155285,
#   'unit': 'µg'},
#  'FOLFD': {'label': 'Folate (food)',
#   'quantity': 3.3283192310155285,
#   'unit': 'µg'},
#  'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#  'VITB12': {'label': 'Vitamin B12',
#   'quantity': 0.23204873079139757,
#   'unit': 'µg'},
#  'VITD': {'label': 'Vitamin D', 'quantity': 0.6703630000640374, 'unit': 'µg'},
#  'TOCPHA': {'label': 'Vitamin E',
#   'quantity': 0.0360964692342174,
#   'unit': 'mg'},
#  'VITK1': {'label': 'Vitamin K', 'quantity': 0.1546991538609317, 'unit': 'µg'},
#  'WATER': {'label': 'Water', 'quantity': 1059.4004547658797, 'unit': 'g'}}

# %%
tea_info['totalNutrients']['SUGAR']
# Out:
# {'label': 'Sugars', 'quantity': 2.6041024233256835, 'unit': 'g'}

# %% [markdown]
# ## Construct a dataframe

# %%
import pandas as pd 
total_nutrients =pd.DataFrame(tea_info['totalNutrients'])

# %%
total_nutrients
# Out:
#          ENERC_KCAL      FAT      FASAT             FAMS             FAPU  \
# label        Energy      Fat  Saturated  Monounsaturated  Polyunsaturated
# quantity    31.6055  1.67591   0.962013         0.418869         0.101154
# unit           kcal        g          g                g                g
#
#            CHOCDF  FIBTG   SUGAR   PROCNT        CHOLE  ...          NIA  \
# label       Carbs  Fiber  Sugars  Protein  Cholesterol  ...  Niacin (B3)
# quantity  2.52019      0  2.6041  1.62434      5.15664  ...    0.0458941
# unit            g      g       g        g           mg  ...           mg
#
#               VITB6A                     FOLDFE          FOLFD       FOLAC  \
# label     Vitamin B6  Folate equivalent (total)  Folate (food)  Folic acid
# quantity   0.0185639                    3.32832        3.32832           0
# unit              mg                         µg             µg          µg
#
#                VITB12       VITD     TOCPHA      VITK1   WATER
# label     Vitamin B12  Vitamin D  Vitamin E  Vitamin K   Water
# quantity     0.232049   0.670363  0.0360965   0.154699  1059.4
# unit               µg         µg         mg         µg       g
#
# [3 rows x 31 columns]

# %%
total_nutrients=total_nutrients.transpose()

# %%
total_nutrients
# Out:
#                                 label   quantity  unit
# ENERC_KCAL                     Energy    31.6055  kcal
# FAT                               Fat    1.67591     g
# FASAT                       Saturated   0.962013     g
# FAMS                  Monounsaturated   0.418869     g
# FAPU                  Polyunsaturated   0.101154     g
# CHOCDF                          Carbs    2.52019     g
# FIBTG                           Fiber          0     g
# SUGAR                          Sugars     2.6041     g
# PROCNT                        Protein    1.62434     g
# CHOLE                     Cholesterol    5.15664    mg
# NA                             Sodium    62.6235    mg
# CA                            Calcium      88.27    mg
# MG                          Magnesium    15.6066    mg
# K                           Potassium    73.6176    mg
# FE                               Iron  0.0184699    mg
# ZN                               Zinc   0.293796    mg
# P                          Phosphorus    43.4658    mg
# VITA_RAE                    Vitamin A    23.7205    µg
# VITC                        Vitamin C          0    mg
# THIA                     Thiamin (B1)  0.0237205    mg
# RIBF                  Riboflavin (B2)  0.0892472    mg
# NIA                       Niacin (B3)  0.0458941    mg
# VITB6A                     Vitamin B6  0.0185639    mg
# FOLDFE      Folate equivalent (total)    3.32832    µg
# FOLFD                   Folate (food)    3.32832    µg
# FOLAC                      Folic acid          0    µg
# VITB12                    Vitamin B12   0.232049    µg
# VITD                        Vitamin D   0.670363    µg
# TOCPHA                      Vitamin E  0.0360965    mg
# VITK1                       Vitamin K   0.154699    µg
# WATER                           Water     1059.4     g

# %%
total_nutrients.columns
# Out:
# Index(['label', 'quantity', 'unit'], dtype='object')

# %% [markdown]
# ## Testing invalid input

# %%
head = {
   'content type':'application/json'
}
recipe = {
    'title':'Tea',
    'ingr': ['Water','15 gm tea leaf','50 ml milk','']
}

# %%
r = requests.post(url,headers=head,json=recipe)

# %%
r.status_code
# Out:
# 555

# %% [markdown]
# **555
# Recipe with insufficient quality to process correctly**
